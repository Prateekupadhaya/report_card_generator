# %%
import pandas as pd
import sklearn 
import matplotlib.pyplot as plt
import sys
import scipy
import numpy as np
import matplotlib
names = ['serial_no','Student No','Name_of_Candidate','Registration','Grade' ,'Gender','Name_of_school' ,'Date_of_Birth' ,'City_of_Residence','Date_and_time_of_test','Country_of_Residence','Extra_time_assistance','Question_No.','Time_Spent_on_question','Score_if_correct','Score_if_incorrect','Attempt_status' ,'What_you_marked','Correct_Answer','Outcome','Your_score']
data_ = pd.read_csv('Assignment.csv',names=names)
data_.head()
# Out:
#    serial_no Student No Name_of_Candidate  Registration Grade Gender  \
# 0        1.0        abc          32030938             2     M    YTH
# 1        NaN          1               abc      32030938     2      M
# 2        NaN          1               abc      32030938     2      M
# 3        NaN          1               abc      32030938     2      M
# 4        NaN          1               abc      32030938     2      M
#
#   Name_of_school Date_of_Birth City_of_Residence Date_and_time_of_test  ...  \
# 0      22-Nov-12         Tokyo         16-Dec-20                 Japan  ...
# 1            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
# 2            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
# 3            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
# 4            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
#
#   Extra_time_assistance Question_No. Time_Spent_on_question  Score_if_correct  \
# ...

# %%
data_['Your score'].plot()

# %%
data_.hist('Time Spent on question (sec)')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f93ace341d0>]],
#       dtype=object)

# %%
student1 = data_[:5]

# %%
student1
# Out:
#    serial_no Student No Name of Candidate  Registration Grade Gender  \
# 0        1.0        abc          32030938             2     M    YTH
# 1        NaN          1               abc      32030938     2      M
# 2        NaN          1               abc      32030938     2      M
# 3        NaN          1               abc      32030938     2      M
# 4        NaN          1               abc      32030938     2      M
#
#   Name of school Date of Birth City of Residence Date and time of test  ...  \
# 0      22-Nov-12         Tokyo         16-Dec-20                 Japan  ...
# 1            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
# 2            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
# 3            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
# 4            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
#
#   Extra time assistance Question No. Time Spent on question (sec)  \
# ...

# %%
plt.title('Commute Times for 1,000 Commuters')
plt.xlabel('Questions')
plt.ylabel('Tiem Taken')
# Out:
# Text(0, 0.5, 'Tiem Taken')

# %%
data_.head()
# Out:
#    serial_no Student No Name of Candidate  Registration Grade Gender  \
# 0        1.0        abc          32030938             2     M    YTH
# 1        NaN          1               abc      32030938     2      M
# 2        NaN          1               abc      32030938     2      M
# 3        NaN          1               abc      32030938     2      M
# 4        NaN          1               abc      32030938     2      M
#
#   Name of school Date of Birth City of Residence Date and time of test  ...  \
# 0      22-Nov-12         Tokyo         16-Dec-20                 Japan  ...
# 1            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
# 2            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
# 3            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
# 4            YTH     22-Nov-12             Tokyo             16-Dec-20  ...
#
#   Extra time assistance Question No. Time Spent on question (sec)  \
# ...

# %%
a = data_.drop([0],axis=0)

# %%
b = a.drop(columns="serial_no")
b
# Out:
#    Student No Name_of_Candidate  Registration Grade Gender Name_of_school  \
# 1           1               abc      32030938     2      M            YTH
# 2           1               abc      32030938     2      M            YTH
# 3           1               abc      32030938     2      M            YTH
# 4           1               abc      32030938     2      M            YTH
# 5           2               afd      92743967     3      F           rtgh
# 6           2               afd      92743967     3      F           rtgh
# 7           2               afd      92743967     3      F           rtgh
# 8           2               afd      92743967     3      F           rtgh
# 9           2               afd      92743967     3      F           rtgh
# 10          3               fds      80989090     4      M            FGD
# 11          3               fds      80989090     4      M            FGD
# 12          3               fds      80989090     4      M            FGD
# ...

# %%
c = b[:5]
c
# Out:
#   Student No Name_of_Candidate  Registration Grade Gender Name_of_school  \
# 1          1               abc      32030938     2      M            YTH
# 2          1               abc      32030938     2      M            YTH
# 3          1               abc      32030938     2      M            YTH
# 4          1               abc      32030938     2      M            YTH
# 5          2               afd      92743967     3      F           rtgh
#
#   Date_of_Birth City_of_Residence Date_and_time_of_test Country_of_Residence  \
# 1     22-Nov-12             Tokyo             16-Dec-20                Japan
# 2     22-Nov-12             Tokyo             16-Dec-20                Japan
# 3     22-Nov-12             Tokyo             16-Dec-20                Japan
# 4     22-Nov-12             Tokyo             16-Dec-20                Japan
# 5     11-Nov-11           Beijing             16-Dec-20                China
#
#   Extra_time_assistance Question_No.  Time_Spent_on_question  \
# ...

# %%
mylist = b['Registration'].tolist()

# %%
mylist[0]
# Out:
# 32030938

# %%
mylist = reg['column name'].tolist()

# %%
for x in reg[]:
    print(x)
# Out:
#   File "<ipython-input-54-c040672645d3>", line 1
#     for x in reg[]:
#                  ^
# SyntaxError: invalid syntax

# %%
a

# %%
# Out:
#    Student No Name of Candidate  Registration Grade Gender Name of school  \
# 0         abc          32030938             2     M    YTH      22-Nov-12
# 1           1               abc      32030938     2      M            YTH
# 2           1               abc      32030938     2      M            YTH
# 3           1               abc      32030938     2      M            YTH
# 4           1               abc      32030938     2      M            YTH
# 5           2               afd      92743967     3      F           rtgh
# 6           2               afd      92743967     3      F           rtgh
# 7           2               afd      92743967     3      F           rtgh
# 8           2               afd      92743967     3      F           rtgh
# 9           2               afd      92743967     3      F           rtgh
# 10          3               fds      80989090     4      M            FGD
# 11          3               fds      80989090     4      M            FGD
# ...
